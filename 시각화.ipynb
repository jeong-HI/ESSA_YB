# %%
import seaborn as sns

# %%
anscombe= sns.load_dataset("anscombe")

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
dataset_1= anscombe[anscombe['dataset'] == 'I']

# %%
plt.plot(dataset_1['x'], dataset_1['y'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
dataset_2 = anscombe[anscombe['dataset'] == 'II']
dataset_3 = anscombe[anscombe['dataset' ] == 'III']
dataset_4 = anscombe[anscombe['dataset' ] == 'IV']

# %%
fig= plt.figure()
axes1= fig.add_subplot(2,2,1)
axes2= fig.add_subplot(2,2,2)
axes3= fig.add_subplot(2,2,3)
axes4= fig.add_subplot(2,2,4)

axes1.plot(dataset_1['x'], dataset_1['y'],'o')
axes2.plot(dataset_2['x'], dataset_2['y'],'o')
axes3.plot(dataset_3['x'], dataset_3['y'],'o')
axes4.plot(dataset_4['x'], dataset_4['y'],'o')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1.set_title("dataset_1")
axes2.set_title("dataset_2")
axes3.set_title("dataset_3")
axes4.set_title("dataset_4")
fig
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig.tight_layout()

# %%
tips= sns.load_dataset("tips")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
axes1.hist(tips['total_bill'], bins=10)
axes1.set_title('Histogram of Total Bill')
# Out:
# Text(0.5, 1.0, 'Histogram of Total Bill')

# %%
scatter_plot= plt.figure()
axes1= scatter_plot.add_subplot(1,1,1)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
axes1.scatter(tips['total_bill'], tips['tip'])

# %%
boxplot= plt.figure()
axes1= boxplot.add_subplot(1,1,1)
axes1.boxplot([tips[tips['sex']=='Female']['tip'], tips[tips['sex']=='Male']['tip']], labels=['Female','Male'])
axes1.set_ylabel('Tip')
axes1.set_xlabel('sex')
axes1.set_title('Boxplot of Tips by Sex')
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Boxplot of Tips by Sex')

# %%
def recode_sex(sex):
    if sex == 'Female':
        return 0
    else:
        return 1

# %%
tips['sex_color']= tips['sex'].apply(recode_sex)

# %%
import seaborn as sns  #seaborn LB를 sns로 줄여서 사용

tips = sns.load_dataset("tips")

# %%
ax = plt.subplots( )
ax = sns.distplot(tips['total_bill'],hist=False)    # 선그래프를 업애고싶으면 kde=False 지정
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ana\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
ax = plt.subplots( )
ax = sns.distplot(tips['total_bill'], rug=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ana\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ana\lib\site-packages\seaborn\distributions.py:2055: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)

# %%
ax= plt.subplots()
ax= sns.countplot('day', data=tips)
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ana\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
ax = plt.subplots( )
ax = sns.regplot(x='total_bill', y='tip', data=tips, fit_reg=False) #fit_reg를 지우면 회귀선도 출력
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
hexbin= sns.jointplot(x='total_bill', y= 'tip', data=tips, kind='hex')
hexbin.set_axis_labels(xlabel='total bill', ylabel='Tip')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
ax= plt.subplots()
ax= sns.kdeplot(data= tips['total_bill'],data2=tips['tip'],shade=True)

hexbin.set_axis_labels(xlabel='total bill', ylabel='Tip')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\ana\lib\site-packages\seaborn\distributions.py:1641: FutureWarning: Use `x` and `y` rather than `data` `and `data2`
#   warnings.warn(msg, FutureWarning)

# %%
ax= plt.subplots()
ax=sns.barplot(x='time', y='total_bill', data=tips)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig= sns.pairplot(tips)
pair_grid = sns.PairGrid(tips)
pair_grid= pair_grid.map_upper(sns.regplot)
pair_grid= pair_grid.map_lower(sns.kdeplot)
pair_grid= pair_grid.map_diag(sns.distplot, rug=True)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="750">
# <img src="data:image/png;base64,..." width="750">

# %%
ax= plt.subplots()
ax= sns.violinplot(x='time', y='total_bill', hue='sex', data=tips, split=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
scatter= sns.lmplot(x='total_bill', y='tip', data= tips, hue='sex', fit_reg=False)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
fig = sns.pairplot(tips, hue='sex')
# Out:
# <img src="data:image/png;base64,..." width="850">

# %%
anscombe_plot= sns.lmplot(x='x', y='y', data=anscombe, fit_reg= False, col='dataset', col_wrap=2)
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
anscombe_plot= sns.lmplot(x='x', y='y', data=anscombe, fit_reg= False, col='dataset', col_wrap=1)
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
facet= sns.FacetGrid(tips, col='time')  # 그래프 축 생성
facet.map(sns.distplot, 'total_bill')  # 그래프종류와 x축에 지정할 열 이름을 전달
# Out:
# <img src="data:image/png;base64,..." width="600">
# C:\ana\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ana\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
facet= sns.FacetGrid(tips, col='day', hue='sex') # 축생성
facet= facet.map(plt.scatter, 'total_bill', 'tip')   # 그리고싶은 plot이름과 x축, y축
facet= facet.add_legend()
# Out:
# <img src="data:image/png;base64,..." width="1300">

# %%
facet= sns.FacetGrid(tips, col='time', row='smoker', hue='sex')
facet.map(plt.scatter, 'total_bill','tip')
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
ax= plt.subplots()
ax= tips['total_bill'].plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax= plt.subplots()
ax= tips[['total_bill','tip']].plot.hist(alpha= 0.5, bins=20, ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots( )
ax = tips.plot.hexbin(x='total_bill', y='tip', gridsize=5,  ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots( )
ax = tips.plot.scatter(x='total_bill', y='tip', ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig, ax = plt.subplots( ) 
ax = tips.plot.box(ax=ax)   # ax=ax 안써주면 축 plot한번 그래프 plot한번 이렇게 두번 나타남
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = plt.figure( )
seaborn_styles = ['darkgrid', 'whitegrid', 'dark', 'white' , 'ticks']
for idx, style in enumerate(seaborn_styles):
    plot_position = idx + 1
    with sns.axes_style(style):
        ax = fig.add_subplot(2, 3, plot_position)
        violin = sns.violinplot(x='time', y='total_bill', data=tips, ax=ax)
        violin.set_title(style)

fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
from datetime import datetime

# %%
print(datetime.now())
# Out:
# 2021-04-05 12:26:05.480968

# %%
import pandas as pd
import os

# %%
test_df1 = pd.DataFrame({'order_day':['01/01/15', '02/01/15', '03/01/15']})

# %%
test_df1['date_dt1']=pd.to_datetime(test_df1['order_day'], format="%d/%m/%y")

# %%
print(test_df1)
# Out:
#   order_day   date_dt1
# 0  01/01/15 2015-01-01
# 1  02/01/15 2015-01-02
# 2  03/01/15 2015-01-03

# %%
now = datetime.now( ) 
print(now)
nowDate = now.strftime('%Y-%m-%d' )
print(nowDate)
nowTime = now.strftime('%H:%M:%S')   # 여기부분에 형식지정자 지정하면 됨
print(nowTime)
# Out:
# 2021-04-05 12:39:35.759915
# 2021-04-05
# 12:39:35

# %%
pip install pandas-datareader
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
pd.core.common.is_list_like = pd.api.types.is_list_like
import pandas_datareader as pdr

# %%
tesla= pd.read_csv('C:/myR/tesla_stock2.csv', parse_dates=[0])

# %%
print(tesla.head())
# Out:
#         Date    Open    High     Low   Close    Volume  ExDividend  \
# 0 2018-03-27  304.00  304.27  277.18  279.18  13696168           0
# 1 2018-03-26  307.34  307.59  291.36  304.18   8324639           0
# 2 2018-03-23  311.25  311.61  300.45  301.54   6600538           0
# 3 2018-03-22  313.89  318.82  308.18  309.10   4914307           0
# 4 2018-03-21  310.25  322.44  310.19  316.53   5927881           0
#
#    SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose  AdjVolume
# 0           1   304.00   304.27  277.18    279.18   13696168
# 1           1   307.34   307.59  291.36    304.18    8324639
# 2           1   311.25   311.61  300.45    301.54    6600538
# 3           1   313.89   318.82  308.18    309.10    4914307
# 4           1   310.25   322.44  310.19    316.53    5927881

# %%
tesla.index = tesla['Date']
print(tesla.index)
# Out:
# DatetimeIndex(['2018-03-27', '2018-03-26', '2018-03-23', '2018-03-22',
#                '2018-03-21', '2018-03-20', '2018-03-19', '2018-03-16',
#                '2018-03-15', '2018-03-14',
#                ...
#                '2010-07-13', '2010-07-12', '2010-07-09', '2010-07-08',
#                '2010-07-07', '2010-07-06', '2010-07-02', '2010-07-01',
#                '2010-06-30', '2010-06-29'],
#               dtype='datetime64[ns]', name='Date', length=1949, freq=None)

# %%
print(tesla['2015'].iloc[:5,:5])
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-23-e6026fbf2efd> in <module>
# ----> 1 print(tesla['2015'].iloc[:5,:5])
#
# C:\ana\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2883             # either we have a slice or we have a string that can be converted
#    2884             #  to a slice for partial-string date indexing
# -> 2885             return self._slice(indexer, axis=0)
#    2886
#    2887         # Do we have a (boolean) DataFrame?
#
# C:\ana\lib\site-packages\pandas\core\generic.py in _slice(self, slobj, axis)
#    3555         Slicing with this method is *always* positional.
#    3556         """
# -> 3557         assert isinstance(slobj, slice), type(slobj)
#    3558         axis = self._get_block_manager_axis(axis)
#    3559         result = self._constructor(self._mgr.get_slice(slobj, axis=axis))
#
# ...
